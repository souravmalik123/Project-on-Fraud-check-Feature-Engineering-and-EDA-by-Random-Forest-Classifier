# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loaded the Data set

# %%
data = pd.read_csv("Fraud_check.csv")

# %%
data.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
data.shape
# Out:
# (600, 6)

# %%
conditions = [(data["Taxable.Income"] <=30000),(data["Taxable.Income"] >30000)]
categories = ["Risky","Good"]

# %%
data["Taxable.Income"] = np.select(conditions,categories)

# %%
data["Taxable.Income"].unique()
# Out:
# array(['Good', 'Risky'], dtype=object)

# %%
data.head()
# Out:
#   Undergrad Marital.Status Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           Good            50047               10
# 1       YES       Divorced           Good           134075               18
# 2        NO        Married           Good           160205               30
# 3       YES         Single           Good           193264               15
# 4        NO        Married           Good            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %% [markdown]
# Missing value
#
# No null values in the dataset

# %%
data.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
data["Undergrad"].value_counts()
# Out:
# YES    312
# NO     288
# Name: Undergrad, dtype: int64

# %%
sns.countplot(x=data["Undergrad"],data=data)
# Out:
# <Axes: xlabel='Undergrad', ylabel='count'>

# %%
sns.countplot(x=data["Undergrad"],hue=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='Undergrad', ylabel='count'>

# %%
data["Marital.Status"].value_counts()
# Out:
# Single      217
# Married     194
# Divorced    189
# Name: Marital.Status, dtype: int64

# %%
sns.countplot(x=data["Marital.Status"],data=data)
# Out:
# <Axes: xlabel='Marital.Status', ylabel='count'>

# %%
sns.countplot(x=data["Marital.Status"],hue=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='Marital.Status', ylabel='count'>

# %%
data["City.Population"].value_counts()
# Out:
# 57194     2
# 162777    2
# 50047     1
# 130912    1
# 64070     1
#          ..
# 145744    1
# 58225     1
# 28661     1
# 117260    1
# 158137    1
# Name: City.Population, Length: 598, dtype: int64

# %%
sns.histplot(x=data["City.Population"],data=data)
# Out:
# <Axes: xlabel='City.Population', ylabel='Count'>

# %%
sns.histplot(x=data["City.Population"],hue=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='City.Population', ylabel='Count'>

# %%
sns.boxplot(x=data["City.Population"])  ### No outliers in the city population column
# Out:
# <Axes: xlabel='City.Population'>

# %%
data["Work.Experience"].unique()
# Out:
# array([10, 18, 30, 15, 28,  0,  8,  3, 12,  4, 19,  6, 14, 16, 13, 29, 25,
#        26,  7, 27,  5, 21, 23,  1, 22,  2, 11,  9, 24, 17, 20],
#       dtype=int64)

# %%
sns.histplot(x=data["Work.Experience"],data=data)
# Out:
# <Axes: xlabel='Work.Experience', ylabel='Count'>

# %%
sns.histplot(x=data["Work.Experience"],hue=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='Work.Experience', ylabel='Count'>

# %%
sns.boxplot(x=data["Work.Experience"])  ### No outliers in the work.experience column
# Out:
# <Axes: xlabel='Work.Experience'>

# %%
data["Urban"].value_counts()
# Out:
# YES    302
# NO     298
# Name: Urban, dtype: int64

# %%
sns.countplot(x=data["Urban"],data=data)
# Out:
# <Axes: xlabel='Urban', ylabel='count'>

# %%
sns.countplot(x=data["Urban"],hue=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='Urban', ylabel='count'>

# %%
sns.countplot(x=data["Taxable.Income"],data=data)
# Out:
# <Axes: xlabel='Taxable.Income', ylabel='count'>

# %%
data.corr()
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_12236\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                  City.Population  Work.Experience
# City.Population         1.000000         0.013135
# Work.Experience         0.013135         1.000000

# %%
sns.heatmap(data.corr(),annot=True,vmin=-1)
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_12236\1039722291.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,vmin=-1)
# <Axes: >
